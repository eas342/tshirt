# %% [markdown]
# # Basic Spectroscopic Pipeline Usage

# %% [markdown]
# First, navigate to the tser_tools directory

# %%
cd ../../tshirt/
# Out:
# /Users/everettschlawin/es_programs/tshirt/tshirt

# %%
from pipeline import spec_pipeline
#spec = spec_pipeline.spec()
spec = spec_pipeline.spec(paramFile='parameters/spec_params/example_spec_parameters.yaml')
spec.do_extraction(useMultiprocessing=True)
# Out:
# On 0 of 4

# %%
spec.plot_one_spec()

# %%
spec.plot_wavebin_series(savePlot=False)
# Out:
# /Users/everettschlawin/es_programs/tshirt/tshirt/pipeline/spec_pipeline.py:1277: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
